# %% [markdown]
# # Data Gather

# %% [markdown]
# ### **library imports**

# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
from scipy.signal import butter, filtfilt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
import pandas as pd
import matplotlib.pyplot as plt
import os  # Add import for os module
from sklearn.utils import resample
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# %% [markdown]
# ### **Initialize MediaPipe Pose**

# %%
'''This script uses MediaPipe to process video frames for pose estimation.'''
mp_pose = mp.solutions.pose  # Access MediaPipe's pose solution
mp_drawing = mp.solutions.drawing_utils  # Utility for drawing landmarks on frames
pose = mp_pose.Pose(
    static_image_mode=False,  # Process video frames in a continuous stream
    min_detection_confidence=0.5,  # Minimum confidence for detecting landmarks
    min_tracking_confidence=0.5  # Minimum confidence for tracking landmarks
)

# %% [markdown]
# ### **Function to calculate the angle between two points in the XOY plane**

# %%
def angle_from_origin_xoy(p1, p2):
    '''Calculate the angle between two points in the XOY plane.
    Args:
        p1 (tuple): Coordinates of the first point (x1, y1).
        p2 (tuple): Coordinates of the second point (x2, y2).
        Returns:
        float: The angle in degrees between the line connecting the two points and the x-axis.'''
    delta_x = p2[0] - p1[0]
    delta_y = p1[1] - p2[1]  # Invert y-axis for Cartesian coordinates
                
    if delta_x == 0 and delta_y == 0:
        return 0.0  # Handle identical points
                
    angle = np.degrees(np.arctan2(delta_y, delta_x))
    angle = abs(angle)  # Convert -180 to -90 to 90 to 180
    if angle > 90:  # Second and third quadrants
        angle = 180 - angle  # Map 90-180 to 90-0            
    return angle

# %%
def draw_angles(frame, origin, target, angle,label):
    # geometry
    cv2.circle(frame, origin, 8, (0,255,0),   -1)
    cv2.circle(frame, target, 8, (0,0,255),   -1)
    cv2.line(  frame, origin, target, (255,255,0), 2)

    # Display metrics text
    x_txt, y_txt = target[0] + 10, max(target[1] - 10, 20)
    cv2.putText(frame, f"{label}: {angle:.1f}", (x_txt, y_txt),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)  # Yellow text

# %%
def butter_lowpass_filter(data, cutoff=0.2, order=4):
        b, a = butter(order, cutoff, btype='low', analog=False)
        return filtfilt(b, a, data)

# %%
scaler = MinMaxScaler()

# %% [markdown]
# ### **Function to process video and calculate angles**

# %%
from typing import Dict

def process_video_and_calculate_angles(video_path, landmarks: Dict[str,int], classification_class):
    # Initialize an empty DataFrame with VideoName column
    columns = ["Frame", "Time"]
    for landmark_name in landmarks.keys():
        columns.extend([
            f"{landmark_name}_Angle",
            f"{landmark_name}_Velocity",
            f"{landmark_name}_Acceleration"
        ])
    
    processed_data = pd.DataFrame(columns=columns)   
    angles_frames_processed_data = pd.DataFrame(columns=columns)
    temporal_data = pd.DataFrame(columns=columns)  # Initialize temporal_data separately

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error opening video.")
        return

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    scale = (1000, 800)
    frame_now = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret or frame is None:
            print("End of video or cannot read the frame.")
            break
        
        print(f"Processing video: {video_path}")
        imagem_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        result = pose.process(imagem_rgb)

        if result.pose_landmarks:
            mp_drawing.draw_landmarks(frame, result.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            # Get reference point (midpoint between hips)
            left_hip = result.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_HIP]
            right_hip = result.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP]
            ref_x = (left_hip.x + right_hip.x) / 2
            ref_y = (left_hip.y + right_hip.y) / 2

            row_data = {
                    "Frame": frame_now,
                    "Time": frame_now / fps
            }

            for landmark_name, landmark_to_compare in landmarks.items():
                # Use the index directly to get the specified landmark
                target_landmark = result.pose_landmarks.landmark[int(landmark_to_compare)]

                # Convert normalized coordinates to image coordinates
                h, w, _ = frame.shape
                ref_pt = (int(ref_x * w), int(ref_y * h))
                target_pt = (int(target_landmark.x * w), int(target_landmark.y * h))

                # Calculate angle
                angule = angle_from_origin_xoy(ref_pt, target_pt)

                if angule is not None:
                    print(f"Frame {frame_now}: {landmark_name} angle: {angule:.2f} degrees")
                    draw_angles(frame, ref_pt, target_pt, angule,landmark_name)                    
                    
                    # Add angle to row_data
                    row_data[f"{landmark_name}_Angle"] = angule
                else:
                    print(f"Frame {frame_now}: Unable to calculate angle.")

            # After processing all landmarks for this frame, append row_data to temporal_data
            temporal_data = pd.concat([temporal_data, pd.DataFrame([row_data])], ignore_index=True)
                
            # Process and show velocity and acceleration for each landmark in the last 30 frames
            if not angles_frames_processed_data.empty:
                for landmark_name in landmarks.keys():
                    last_velocity = angles_frames_processed_data[f"{landmark_name}_Velocity"].dropna().mean()
                    last_acceleration = angles_frames_processed_data[f"{landmark_name}_Acceleration"].dropna().mean()
                                # Improved text formatting with consistent dynamic positioning
                y_offset = 30  # Initial vertical offset
                x_offset = 10  # Horizontal offset for text placement

                for i, landmark_name in enumerate(landmarks.keys()):
                    last_velocity = angles_frames_processed_data[f"{landmark_name}_Velocity"].dropna().iloc[-1]
                    last_acceleration = angles_frames_processed_data[f"{landmark_name}_Acceleration"].dropna().iloc[-1]
                        
                    # Format text
                    text = f"{landmark_name} - Velocity: {last_velocity:.2f} / Acceleration: {last_acceleration:.2f}"
                        
                    # Adjust position dynamically
                    cv2.putText(frame, text, (x_offset, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2, cv2.LINE_AA)
                        
                    y_offset += 30  # Ensure enough spacing between annotations
                                  
            # Every second, append data to angles_processed_data and clear temporal_data
            if (frame_now) % fps == 0:
                # Calculate velocity and acceleration for each landmark angle
                for landmark_name in landmarks.keys():
                    angle_col = f"{landmark_name}_Angle"
                    velocity_col = f"{landmark_name}_Velocity"
                    acceleration_col = f"{landmark_name}_Acceleration"
                    
                    # Apply Butterworth lowpass filter to smooth the angle data
                    temporal_data[f"{angle_col}_filtered"] = butter_lowpass_filter(temporal_data[angle_col].astype(float))
                    
                    # Calculate velocity and acceleration
                    temporal_data[velocity_col] = np.gradient(temporal_data[angle_col], temporal_data["Frame"])
                    temporal_data[acceleration_col] = np.gradient(temporal_data[velocity_col], temporal_data["Frame"])
                    
                    # Normalize velocity and acceleration for each landmark
                    temporal_data[[f"{velocity_col}_normalized", f"{acceleration_col}_normalized"]] = scaler.fit_transform(
                        temporal_data[[velocity_col, acceleration_col]]
                    )
                print(f"Processed angles for frame {frame_now}:")
                # Append the processed temporal data to angles_frames_processed_data
                angles_frames_processed_data = pd.concat([temporal_data], ignore_index=True)
                # Append the processed temporal data to processed_data
                processed_data = pd.concat([processed_data,temporal_data], ignore_index=True)
                temporal_data = temporal_data.iloc[0:0]  # Clear the DataFrame for the next batch                        
                    
        frame_resized = cv2.resize(frame, scale)
        cv2.imshow("Angle Visualization", frame_resized)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        frame_now += 1
        
    cap.release()
    cv2.destroyAllWindows()
    
    processed_data["Classification"] = classification_class
    processed_data["Video Name"] = os.path.basename(video_path)  # Add video name to DataFrame
    
    return processed_data

# %% [markdown]
# ### **Define the landmarks of interest**

# %%
landmarks_ids = {
    "head": 0,  # Head (nose landmark)
    "left_wrist": 15,  # Left wrist
    "right_wrist": 16,  # Right wrist
    "left_ankle": 27,  # Left ankle
    "right_ankle": 28  # Right ankle
}
print("Landmarks de interesse definidos:", landmarks_ids)
# Out:
# Landmarks de interesse definidos: {'head': 0, 'left_wrist': 15, 'right_wrist': 16, 'left_ankle': 27, 'right_ankle': 28}

# %% [markdown]
# ### **Gather data from videos**

# %%
videos_folder = '.\\Videos\\'
data_folder = '.\\Data\\'
videos = {
    'direct.MOV': 'direct',
    'impro_free.MP4': 'direct',    
    'indirect(cut).mp4': 'indirect',
    'Phrase3.mp4': 'indirect',
    'sustained (direct).MOV': 'direct',
    'sustained (indirect).MOV': 'indirect',
}

def get_videos_data(videos, landmarks, data_folder, videos_folder):
    for video, classification in videos.items():
            video_landmark_processed_data = process_video_and_calculate_angles(
            os.path.join(videos_folder, video), landmarks, classification)
            landmark_processed_data = pd.concat([landmark_processed_data, video_landmark_processed_data], ignore_index=True) if 'landmark_processed_data' in locals() else video_landmark_processed_data
    return landmark_processed_data

landmark_processed_data = get_videos_data(videos, landmarks_ids, data_folder, videos_folder)
landmark_processed_data.to_csv(os.path.join(data_folder, 'landmark_processed_data.csv'), index=False)
# Out:
# Processing video: .\Videos\impro_free.MP4
# Processing video: .\Videos\impro_free.MP4
# Frame 1: head angle: 89.70 degrees
# Frame 1: left_wrist angle: 67.78 degrees
# Frame 1: right_wrist angle: 58.11 degrees
# Frame 1: left_ankle angle: 79.88 degrees
# Frame 1: right_ankle angle: 81.08 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 2: head angle: 88.80 degrees
# Frame 2: left_wrist angle: 73.80 degrees
# Frame 2: right_wrist angle: 65.39 degrees
# Frame 2: left_ankle angle: 79.71 degrees
# Frame 2: right_ankle angle: 80.42 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 3: head angle: 87.01 degrees
# Frame 3: left_wrist angle: 86.84 degrees
# Frame 3: right_wrist angle: 72.34 degrees
# Frame 3: left_ankle angle: 80.76 degrees
# Frame 3: right_ankle angle: 79.56 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 4: head angle: 83.12 degrees
# Frame 4: left_wrist angle: 87.78 degrees
# Frame 4: right_wrist angle: 71.93 degrees
# Frame 4: left_ankle angle: 81.80 degrees
# Frame 4: right_ankle angle: 77.79 degrees
# Processing video: .\Videos\impro_free.MP4
# C:\Users\asus\AppData\Local\Temp\ipykernel_38832\3318161601.py:72: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   temporal_data = pd.concat([temporal_data, pd.DataFrame([row_data])], ignore_index=True)
# Frame 5: head angle: 79.72 degrees
# Frame 5: left_wrist angle: 80.50 degrees
# Frame 5: right_wrist angle: 68.60 degrees
# Frame 5: left_ankle angle: 82.49 degrees
# Frame 5: right_ankle angle: 75.35 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 6: head angle: 75.08 degrees
# Frame 6: left_wrist angle: 75.82 degrees
# Frame 6: right_wrist angle: 74.58 degrees
# Frame 6: left_ankle angle: 85.53 degrees
# Frame 6: right_ankle angle: 73.50 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 7: head angle: 71.77 degrees
# Frame 7: left_wrist angle: 74.01 degrees
# Frame 7: right_wrist angle: 71.36 degrees
# Frame 7: left_ankle angle: 86.60 degrees
# Frame 7: right_ankle angle: 73.09 degrees
# Processing video: .\Videos\impro_free.MP4
# Processing video: .\Videos\impro_free.MP4
# Frame 9: head angle: 74.76 degrees
# Frame 9: left_wrist angle: 65.07 degrees
# Frame 9: right_wrist angle: 32.41 degrees
# Frame 9: left_ankle angle: 79.82 degrees
# Frame 9: right_ankle angle: 65.91 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 10: head angle: 75.21 degrees
# Frame 10: left_wrist angle: 65.20 degrees
# Frame 10: right_wrist angle: 10.57 degrees
# Frame 10: left_ankle angle: 84.30 degrees
# Frame 10: right_ankle angle: 65.21 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 11: head angle: 78.41 degrees
# Frame 11: left_wrist angle: 69.53 degrees
# Frame 11: right_wrist angle: 10.58 degrees
# Frame 11: left_ankle angle: 83.51 degrees
# Frame 11: right_ankle angle: 63.06 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 12: head angle: 79.39 degrees
# Frame 12: left_wrist angle: 82.61 degrees
# Frame 12: right_wrist angle: 13.37 degrees
# Frame 12: left_ankle angle: 81.87 degrees
# Frame 12: right_ankle angle: 62.19 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 13: head angle: 80.19 degrees
# Frame 13: left_wrist angle: 84.77 degrees
# Frame 13: right_wrist angle: 14.69 degrees
# Frame 13: left_ankle angle: 81.91 degrees
# Frame 13: right_ankle angle: 60.12 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 14: head angle: 80.76 degrees
# Frame 14: left_wrist angle: 68.52 degrees
# Frame 14: right_wrist angle: 4.99 degrees
# Frame 14: left_ankle angle: 80.19 degrees
# Frame 14: right_ankle angle: 58.90 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 15: head angle: 81.72 degrees
# Frame 15: left_wrist angle: 57.57 degrees
# Frame 15: right_wrist angle: 2.75 degrees
# Frame 15: left_ankle angle: 59.45 degrees
# Frame 15: right_ankle angle: 77.39 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 16: head angle: 84.74 degrees
# Frame 16: left_wrist angle: 51.29 degrees
# Frame 16: right_wrist angle: 5.59 degrees
# Frame 16: left_ankle angle: 61.04 degrees
# Frame 16: right_ankle angle: 71.66 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 17: head angle: 88.25 degrees
# Frame 17: left_wrist angle: 50.39 degrees
# Frame 17: right_wrist angle: 19.72 degrees
# Frame 17: left_ankle angle: 69.11 degrees
# Frame 17: right_ankle angle: 66.40 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 18: head angle: 87.53 degrees
# Frame 18: left_wrist angle: 49.26 degrees
# Frame 18: right_wrist angle: 61.53 degrees
# Frame 18: left_ankle angle: 75.85 degrees
# Frame 18: right_ankle angle: 66.60 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 19: head angle: 88.60 degrees
# Frame 19: left_wrist angle: 49.71 degrees
# Frame 19: right_wrist angle: 43.33 degrees
# Frame 19: left_ankle angle: 77.99 degrees
# Frame 19: right_ankle angle: 71.42 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 20: head angle: 89.83 degrees
# Frame 20: left_wrist angle: 53.63 degrees
# Frame 20: right_wrist angle: 47.73 degrees
# Frame 20: left_ankle angle: 79.04 degrees
# Frame 20: right_ankle angle: 73.26 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 21: head angle: 89.85 degrees
# Frame 21: left_wrist angle: 59.43 degrees
# Frame 21: right_wrist angle: 24.19 degrees
# Frame 21: left_ankle angle: 79.83 degrees
# Frame 21: right_ankle angle: 76.51 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 22: head angle: 89.69 degrees
# Frame 22: left_wrist angle: 62.30 degrees
# Frame 22: right_wrist angle: 11.20 degrees
# Frame 22: left_ankle angle: 81.80 degrees
# Frame 22: right_ankle angle: 79.75 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 23: head angle: 89.38 degrees
# Frame 23: left_wrist angle: 71.72 degrees
# Frame 23: right_wrist angle: 4.69 degrees
# Frame 23: left_ankle angle: 83.54 degrees
# Frame 23: right_ankle angle: 82.74 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 24: head angle: 89.53 degrees
# Frame 24: left_wrist angle: 82.34 degrees
# Frame 24: right_wrist angle: 3.81 degrees
# Frame 24: left_ankle angle: 85.58 degrees
# Frame 24: right_ankle angle: 85.58 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 25: head angle: 88.57 degrees
# Frame 25: left_wrist angle: 86.86 degrees
# Frame 25: right_wrist angle: 4.17 degrees
# Frame 25: left_ankle angle: 88.00 degrees
# Frame 25: right_ankle angle: 88.58 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 26: head angle: 89.52 degrees
# Frame 26: left_wrist angle: 80.52 degrees
# Frame 26: right_wrist angle: 4.72 degrees
# Frame 26: left_ankle angle: 89.38 degrees
# Frame 26: right_ankle angle: 88.58 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 27: head angle: 89.19 degrees
# Frame 27: left_wrist angle: 74.99 degrees
# Frame 27: right_wrist angle: 5.03 degrees
# Frame 27: left_ankle angle: 87.97 degrees
# Frame 27: right_ankle angle: 86.24 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 28: head angle: 88.81 degrees
# Frame 28: left_wrist angle: 71.86 degrees
# Frame 28: right_wrist angle: 6.90 degrees
# Frame 28: left_ankle angle: 87.11 degrees
# Frame 28: right_ankle angle: 85.03 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 29: head angle: 88.98 degrees
# Frame 29: left_wrist angle: 71.45 degrees
# Frame 29: right_wrist angle: 8.36 degrees
# Frame 29: left_ankle angle: 86.70 degrees
# Frame 29: right_ankle angle: 85.54 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 30: head angle: 89.49 degrees
# Frame 30: left_wrist angle: 72.59 degrees
# Frame 30: right_wrist angle: 4.46 degrees
# Frame 30: left_ankle angle: 87.19 degrees
# Frame 30: right_ankle angle: 86.94 degrees
# Processed angles for frame 30:
# Processing video: .\Videos\impro_free.MP4
# Frame 31: head angle: 88.61 degrees
# Frame 31: left_wrist angle: 72.84 degrees
# Frame 31: right_wrist angle: 0.87 degrees
# Frame 31: left_ankle angle: 89.46 degrees
# Frame 31: right_ankle angle: 89.51 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 32: head angle: 86.82 degrees
# Frame 32: left_wrist angle: 73.92 degrees
# Frame 32: right_wrist angle: 2.84 degrees
# Frame 32: left_ankle angle: 82.44 degrees
# Frame 32: right_ankle angle: 89.48 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 33: head angle: 84.32 degrees
# Frame 33: left_wrist angle: 77.72 degrees
# Frame 33: right_wrist angle: 5.71 degrees
# Frame 33: left_ankle angle: 77.16 degrees
# Frame 33: right_ankle angle: 86.05 degrees
# Processing video: .\Videos\impro_free.MP4
# C:\Users\asus\AppData\Local\Temp\ipykernel_38832\3318161601.py:118: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   processed_data = pd.concat([processed_data,temporal_data], ignore_index=True)
# Frame 34: head angle: 83.54 degrees
# Frame 34: left_wrist angle: 83.77 degrees
# Frame 34: right_wrist angle: 14.25 degrees
# Frame 34: left_ankle angle: 72.95 degrees
# Frame 34: right_ankle angle: 82.50 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 35: head angle: 83.72 degrees
# Frame 35: left_wrist angle: 88.49 degrees
# Frame 35: right_wrist angle: 32.15 degrees
# Frame 35: left_ankle angle: 75.96 degrees
# Frame 35: right_ankle angle: 79.36 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 36: head angle: 85.49 degrees
# Frame 36: left_wrist angle: 88.16 degrees
# Frame 36: right_wrist angle: 42.40 degrees
# Frame 36: left_ankle angle: 75.55 degrees
# Frame 36: right_ankle angle: 71.45 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 37: head angle: 87.11 degrees
# Frame 37: left_wrist angle: 88.94 degrees
# Frame 37: right_wrist angle: 19.18 degrees
# Frame 37: left_ankle angle: 75.51 degrees
# Frame 37: right_ankle angle: 73.47 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 38: head angle: 89.04 degrees
# Frame 38: left_wrist angle: 87.31 degrees
# Frame 38: right_wrist angle: 7.52 degrees
# Frame 38: left_ankle angle: 76.23 degrees
# Frame 38: right_ankle angle: 75.00 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 39: head angle: 89.62 degrees
# Frame 39: left_wrist angle: 82.37 degrees
# Frame 39: right_wrist angle: 3.45 degrees
# Frame 39: left_ankle angle: 77.89 degrees
# Frame 39: right_ankle angle: 77.57 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 40: head angle: 89.62 degrees
# Frame 40: left_wrist angle: 79.91 degrees
# Frame 40: right_wrist angle: 4.68 degrees
# Frame 40: left_ankle angle: 79.03 degrees
# Frame 40: right_ankle angle: 77.74 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 41: head angle: 89.44 degrees
# Frame 41: left_wrist angle: 77.20 degrees
# Frame 41: right_wrist angle: 10.23 degrees
# Frame 41: left_ankle angle: 77.72 degrees
# Frame 41: right_ankle angle: 79.62 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 42: head angle: 90.00 degrees
# Frame 42: left_wrist angle: 74.74 degrees
# Frame 42: right_wrist angle: 9.01 degrees
# Frame 42: left_ankle angle: 84.66 degrees
# Frame 42: right_ankle angle: 77.53 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 43: head angle: 89.45 degrees
# Frame 43: left_wrist angle: 71.09 degrees
# Frame 43: right_wrist angle: 8.72 degrees
# Frame 43: left_ankle angle: 87.27 degrees
# Frame 43: right_ankle angle: 76.88 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 44: head angle: 89.82 degrees
# Frame 44: left_wrist angle: 69.26 degrees
# Frame 44: right_wrist angle: 11.06 degrees
# Frame 44: left_ankle angle: 88.70 degrees
# Frame 44: right_ankle angle: 75.59 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 45: head angle: 89.83 degrees
# Frame 45: left_wrist angle: 64.51 degrees
# Frame 45: right_wrist angle: 16.12 degrees
# Frame 45: left_ankle angle: 85.27 degrees
# Frame 45: right_ankle angle: 72.07 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 46: head angle: 89.82 degrees
# Frame 46: left_wrist angle: 60.46 degrees
# Frame 46: right_wrist angle: 16.76 degrees
# Frame 46: left_ankle angle: 86.40 degrees
# Frame 46: right_ankle angle: 67.37 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 47: head angle: 89.47 degrees
# Frame 47: left_wrist angle: 56.17 degrees
# Frame 47: right_wrist angle: 18.10 degrees
# Frame 47: left_ankle angle: 87.78 degrees
# Frame 47: right_ankle angle: 63.78 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 48: head angle: 88.28 degrees
# Frame 48: left_wrist angle: 50.98 degrees
# Frame 48: right_wrist angle: 16.37 degrees
# Frame 48: left_ankle angle: 88.50 degrees
# Frame 48: right_ankle angle: 62.04 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 49: head angle: 87.82 degrees
# Frame 49: left_wrist angle: 45.00 degrees
# Frame 49: right_wrist angle: 21.80 degrees
# Frame 49: left_ankle angle: 89.35 degrees
# Frame 49: right_ankle angle: 61.96 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 50: head angle: 86.54 degrees
# Frame 50: left_wrist angle: 40.30 degrees
# Frame 50: right_wrist angle: 31.40 degrees
# Frame 50: left_ankle angle: 88.69 degrees
# Frame 50: right_ankle angle: 61.27 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 51: head angle: 86.21 degrees
# Frame 51: left_wrist angle: 35.95 degrees
# Frame 51: right_wrist angle: 50.65 degrees
# Frame 51: left_ankle angle: 88.24 degrees
# Frame 51: right_ankle angle: 61.73 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 52: head angle: 87.40 degrees
# Frame 52: left_wrist angle: 39.88 degrees
# Frame 52: right_wrist angle: 58.63 degrees
# Frame 52: left_ankle angle: 85.33 degrees
# Frame 52: right_ankle angle: 71.87 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 53: head angle: 88.88 degrees
# Frame 53: left_wrist angle: 37.67 degrees
# Frame 53: right_wrist angle: 43.49 degrees
# Frame 53: left_ankle angle: 85.57 degrees
# Frame 53: right_ankle angle: 79.82 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 54: head angle: 89.77 degrees
# Frame 54: left_wrist angle: 42.61 degrees
# Frame 54: right_wrist angle: 34.33 degrees
# Frame 54: left_ankle angle: 85.49 degrees
# Frame 54: right_ankle angle: 86.66 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 55: head angle: 87.57 degrees
# Frame 55: left_wrist angle: 86.42 degrees
# Frame 55: right_wrist angle: 31.61 degrees
# Frame 55: left_ankle angle: 85.94 degrees
# Frame 55: right_ankle angle: 88.13 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 56: head angle: 84.02 degrees
# Frame 56: left_wrist angle: 22.62 degrees
# Frame 56: right_wrist angle: 18.43 degrees
# Frame 56: left_ankle angle: 87.23 degrees
# Frame 56: right_ankle angle: 83.09 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 57: head angle: 79.96 degrees
# Frame 57: left_wrist angle: 12.88 degrees
# Frame 57: right_wrist angle: 9.34 degrees
# Frame 57: left_ankle angle: 88.50 degrees
# Frame 57: right_ankle angle: 69.38 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 58: head angle: 78.10 degrees
# Frame 58: left_wrist angle: 9.64 degrees
# Frame 58: right_wrist angle: 5.77 degrees
# Frame 58: left_ankle angle: 88.69 degrees
# Frame 58: right_ankle angle: 67.10 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 59: head angle: 75.12 degrees
# Frame 59: left_wrist angle: 10.62 degrees
# Frame 59: right_wrist angle: 0.56 degrees
# Frame 59: left_ankle angle: 89.34 degrees
# Frame 59: right_ankle angle: 63.43 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 60: head angle: 72.97 degrees
# Frame 60: left_wrist angle: 11.89 degrees
# Frame 60: right_wrist angle: 5.76 degrees
# Frame 60: left_ankle angle: 89.33 degrees
# Frame 60: right_ankle angle: 61.98 degrees
# Processed angles for frame 60:
# Processing video: .\Videos\impro_free.MP4
# Frame 61: head angle: 71.18 degrees
# Frame 61: left_wrist angle: 11.82 degrees
# Frame 61: right_wrist angle: 10.04 degrees
# Frame 61: left_ankle angle: 89.33 degrees
# Frame 61: right_ankle angle: 62.53 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame
degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 76: head angle: 78.73 degrees
# Frame 76: left_wrist angle: 4.35 degrees
# Frame 76: right_wrist angle: 65.15 degrees
# Frame 76: left_ankle angle: 88.61 degrees
# Frame 76: right_ankle angle: 89.72 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 77: head angle: 80.15 degrees
# Frame 77: left_wrist angle: 4.35 degrees
# Frame 77: right_wrist angle: 63.76 degrees
# Frame 77: left_ankle angle: 88.61 degrees
# Frame 77: right_ankle angle: 88.48 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 78: head angle: 80.73 degrees
# Frame 78: left_wrist angle: 0.62 degrees
# Frame 78: right_wrist angle: 61.83 degrees
# Frame 78: left_ankle angle: 88.36 degrees
# Frame 78: right_ankle angle: 89.31 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 79: head angle: 80.94 degrees
# Frame 79: left_wrist angle: 3.04 degrees
# Frame 79: right_wrist angle: 60.50 degrees
# Frame 79: left_ankle angle: 87.38 degrees
# Frame 79: right_ankle angle: 90.00 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 80: head angle: 80.95 degrees
# Frame 80: left_wrist angle: 4.81 degrees
# Frame 80: right_wrist angle: 59.58 degrees
# Frame 80: left_ankle angle: 84.60 degrees
# Frame 80: right_ankle angle: 86.30 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 81: head angle: 80.50 degrees
# Frame 81: left_wrist angle: 5.36 degrees
# Frame 81: right_wrist angle: 59.38 degrees
# Frame 81: left_ankle angle: 80.48 degrees
# Frame 81: right_ankle angle: 84.66 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 82: head angle: 80.07 degrees
# Frame 82: left_wrist angle: 8.70 degrees
# Frame 82: right_wrist angle: 59.65 degrees
# Frame 82: left_ankle angle: 78.69 degrees
# Frame 82: right_ankle angle: 85.71 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 83: head angle: 79.98 degrees
# Frame 83: left_wrist angle: 9.74 degrees
# Frame 83: right_wrist angle: 60.06 degrees
# Frame 83: left_ankle angle: 78.61 degrees
# Frame 83: right_ankle angle: 85.26 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 84: head angle: 78.07 degrees
# Frame 84: left_wrist angle: 10.30 degrees
# Frame 84: right_wrist angle: 59.90 degrees
# Frame 84: left_ankle angle: 79.38 degrees
# Frame 84: right_ankle angle: 84.78 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 85: head angle: 74.09 degrees
# Frame 85: left_wrist angle: 10.55 degrees
# Frame 85: right_wrist angle: 61.41 degrees
# Frame 85: left_ankle angle: 82.11 degrees
# Frame 85: right_ankle angle: 82.61 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 86: head angle: 73.46 degrees
# Frame 86: left_wrist angle: 9.21 degrees
# Frame 86: right_wrist angle: 63.43 degrees
# Frame 86: left_ankle angle: 82.41 degrees
# Frame 86: right_ankle angle: 84.59 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 87: head angle: 72.70 degrees
# Frame 87: left_wrist angle: 8.13 degrees
# Frame 87: right_wrist angle: 64.16 degrees
# Frame 87: left_ankle angle: 82.19 degrees
# Frame 87: right_ankle angle: 89.38 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 88: head angle: 71.57 degrees
# Frame 88: left_wrist angle: 6.58 degrees
# Frame 88: right_wrist angle: 64.95 degrees
# Frame 88: left_ankle angle: 82.29 degrees
# Frame 88: right_ankle angle: 84.86 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 89: head angle: 71.73 degrees
# Frame 89: left_wrist angle: 3.60 degrees
# Frame 89: right_wrist angle: 66.93 degrees
# Frame 89: left_ankle angle: 83.45 degrees
# Frame 89: right_ankle angle: 81.59 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 90: head angle: 71.73 degrees
# Frame 90: left_wrist angle: 0.36 degrees
# Frame 90: right_wrist angle: 69.18 degrees
# Frame 90: left_ankle angle: 83.02 degrees
# Frame 90: right_ankle angle: 76.77 degrees
# Processed angles for frame 90:
# Processing video: .\Videos\impro_free.MP4
# Frame 91: head angle: 71.16 degrees
# Frame 91: left_wrist angle: 5.28 degrees
# Frame 91: right_wrist angle: 70.24 degrees
# Frame 91: left_ankle angle: 81.56 degrees
# Frame 91: right_ankle angle: 72.14 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 92: head angle: 71.64 degrees
# Frame 92: left_wrist angle: 10.58 degrees
# Frame 92: right_wrist angle: 71.43 degrees
# Frame 92: left_ankle angle: 80.14 degrees
# Frame 92: right_ankle angle: 69.47 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 93: head angle: 72.32 degrees
# Frame 93: left_wrist angle: 14.55 degrees
# Frame 93: right_wrist angle: 72.77 degrees
# Frame 93: left_ankle angle: 78.78 degrees
# Frame 93: right_ankle angle: 68.04 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 94: head angle: 73.32 degrees
# Frame 94: left_wrist angle: 17.72 degrees
# Frame 94: right_wrist angle: 73.38 degrees
# Frame 94: left_ankle angle: 77.57 degrees
# Frame 94: right_ankle angle: 68.36 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 95: head angle: 74.98 degrees
# Frame 95: left_wrist angle: 21.95 degrees
# Frame 95: right_wrist angle: 74.27 degrees
# Frame 95: left_ankle angle: 76.02 degrees
# Frame 95: right_ankle angle: 69.52 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 96: head angle: 75.12 degrees
# Frame 96: left_wrist angle: 26.10 degrees
# Frame 96: right_wrist angle: 74.97 degrees
# Frame 96: left_ankle angle: 74.83 degrees
# Frame 96: right_ankle angle: 71.42 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 97: head angle: 76.76 degrees
# Frame 97: left_wrist angle: 28.27 degrees
# Frame 97: right_wrist angle: 75.87 degrees
# Frame 97: left_ankle angle: 73.90 degrees
# Frame 97: right_ankle angle: 73.00 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 98: head angle: 77.78 degrees
# Frame 98: left_wrist angle: 30.33 degrees
# Frame 98: right_wrist angle: 76.30 degrees
# Frame 98: left_ankle angle: 72.86 degrees
# Frame 98: right_ankle angle: 74.76 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 99: head angle: 78.65 degrees
# Frame 99: left_wrist angle: 32.08 degrees
# Frame 99: right_wrist angle: 76.60 degrees
# Frame 99: left_ankle angle: 71.28 degrees
# Frame 99: right_ankle angle: 76.18 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 100: head angle: 79.57 degrees
# Frame 100: left_wrist angle: 33.23 degrees
# Frame 100: right_wrist angle: 79.09 degrees
# Frame 100: left_ankle angle: 68.98 degrees
# Frame 100: right_ankle angle: 77.16 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 101: head angle: 80.81 degrees
# Frame 101: left_wrist angle: 33.75 degrees
# Frame 101: right_wrist angle: 80.30 degrees
# Frame 101: left_ankle angle: 66.17 degrees
# Frame 101: right_ankle angle: 78.86 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 102: head angle: 81.96 degrees
# Frame 102: left_wrist angle: 33.88 degrees
# Frame 102: right_wrist angle: 83.49 degrees
# Frame 102: left_ankle angle: 62.52 degrees
# Frame 102: right_ankle angle: 80.39 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 103: head angle: 83.35 degrees
# Frame 103: left_wrist angle: 34.55 degrees
# Frame 103: right_wrist angle: 46.49 degrees
# Frame 103: left_ankle angle: 57.21 degrees
# Frame 103: right_ankle angle: 81.51 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame
degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 133: head angle: 84.29 degrees
# Frame 133: left_wrist angle: 40.74 degrees
# Frame 133: right_wrist angle: 30.82 degrees
# Frame 133: left_ankle angle: 81.64 degrees
# Frame 133: right_ankle angle: 74.84 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 134: head angle: 82.02 degrees
# Frame 134: left_wrist angle: 42.57 degrees
# Frame 134: right_wrist angle: 29.36 degrees
# Frame 134: left_ankle angle: 86.44 degrees
# Frame 134: right_ankle angle: 83.37 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 135: head angle: 81.56 degrees
# Frame 135: left_wrist angle: 45.73 degrees
# Frame 135: right_wrist angle: 28.18 degrees
# Frame 135: left_ankle angle: 80.39 degrees
# Frame 135: right_ankle angle: 76.08 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 136: head angle: 81.30 degrees
# Frame 136: left_wrist angle: 49.61 degrees
# Frame 136: right_wrist angle: 28.36 degrees
# Frame 136: left_ankle angle: 84.20 degrees
# Frame 136: right_ankle angle: 74.39 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 137: head angle: 80.87 degrees
# Frame 137: left_wrist angle: 53.51 degrees
# Frame 137: right_wrist angle: 27.57 degrees
# Frame 137: left_ankle angle: 80.50 degrees
# Frame 137: right_ankle angle: 70.08 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 138: head angle: 80.41 degrees
# Frame 138: left_wrist angle: 57.44 degrees
# Frame 138: right_wrist angle: 29.80 degrees
# Frame 138: left_ankle angle: 79.20 degrees
# Frame 138: right_ankle angle: 64.89 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 139: head angle: 79.75 degrees
# Frame 139: left_wrist angle: 62.79 degrees
# Frame 139: right_wrist angle: 28.93 degrees
# Frame 139: left_ankle angle: 80.33 degrees
# Frame 139: right_ankle angle: 57.69 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 140: head angle: 79.05 degrees
# Frame 140: left_wrist angle: 75.75 degrees
# Frame 140: right_wrist angle: 68.13 degrees
# Frame 140: left_ankle angle: 82.21 degrees
# Frame 140: right_ankle angle: 52.13 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 141: head angle: 79.32 degrees
# Frame 141: left_wrist angle: 86.68 degrees
# Frame 141: right_wrist angle: 78.89 degrees
# Frame 141: left_ankle angle: 83.64 degrees
# Frame 141: right_ankle angle: 46.24 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 142: head angle: 79.01 degrees
# Frame 142: left_wrist angle: 75.61 degrees
# Frame 142: right_wrist angle: 31.87 degrees
# Frame 142: left_ankle angle: 84.27 degrees
# Frame 142: right_ankle angle: 40.16 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 143: head angle: 78.30 degrees
# Frame 143: left_wrist angle: 75.63 degrees
# Frame 143: right_wrist angle: 24.51 degrees
# Frame 143: left_ankle angle: 40.45 degrees
# Frame 143: right_ankle angle: 87.99 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 144: head angle: 79.20 degrees
# Frame 144: left_wrist angle: 78.06 degrees
# Frame 144: right_wrist angle: 21.95 degrees
# Frame 144: left_ankle angle: 60.09 degrees
# Frame 144: right_ankle angle: 33.26 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 145: head angle: 78.93 degrees
# Frame 145: left_wrist angle: 78.53 degrees
# Frame 145: right_wrist angle: 21.21 degrees
# Frame 145: left_ankle angle: 64.97 degrees
# Frame 145: right_ankle angle: 27.03 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 146: head angle: 79.32 degrees
# Frame 146: left_wrist angle: 78.95 degrees
# Frame 146: right_wrist angle: 18.82 degrees
# Frame 146: left_ankle angle: 86.86 degrees
# Frame 146: right_ankle angle: 21.71 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame
degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 175: head angle: 19.24 degrees
# Frame 175: left_wrist angle: 80.54 degrees
# Frame 175: right_wrist angle: 7.49 degrees
# Frame 175: left_ankle angle: 77.84 degrees
# Frame 175: right_ankle angle: 78.50 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 176: head angle: 17.19 degrees
# Frame 176: left_wrist angle: 59.04 degrees
# Frame 176: right_wrist angle: 4.80 degrees
# Frame 176: left_ankle angle: 77.12 degrees
# Frame 176: right_ankle angle: 79.51 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 177: head angle: 14.31 degrees
# Frame 177: left_wrist angle: 12.99 degrees
# Frame 177: right_wrist angle: 2.78 degrees
# Frame 177: left_ankle angle: 78.77 degrees
# Frame 177: right_ankle angle: 80.54 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 178: head angle: 11.65 degrees
# Frame 178: left_wrist angle: 13.57 degrees
# Frame 178: right_wrist angle: 4.57 degrees
# Frame 178: left_ankle angle: 84.90 degrees
# Frame 178: right_ankle angle: 81.22 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 179: head angle: 15.86 degrees
# Frame 179: left_wrist angle: 15.52 degrees
# Frame 179: right_wrist angle: 5.71 degrees
# Frame 179: left_ankle angle: 80.60 degrees
# Frame 179: right_ankle angle: 82.97 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 180: head angle: 21.39 degrees
# Frame 180: left_wrist angle: 48.81 degrees
# Frame 180: right_wrist angle: 40.34 degrees
# Frame 180: left_ankle angle: 80.47 degrees
# Frame 180: right_ankle angle: 83.30 degrees
# Processed angles for frame 180:
# Processing video: .\Videos\impro_free.MP4
# Frame 181: head angle: 20.07 degrees
# Frame 181: left_wrist angle: 34.99 degrees
# Frame 181: right_wrist angle: 46.85 degrees
# Frame 181: left_ankle angle: 80.76 degrees
# Frame 181: right_ankle angle: 85.20 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 182: head angle: 21.90 degrees
# Frame 182: left_wrist angle: 56.31 degrees
# Frame 182: right_wrist angle: 59.36 degrees
# Frame 182: left_ankle angle: 82.44 degrees
# Frame 182: right_ankle angle: 86.25 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 183: head angle: 18.60 degrees
# Frame 183: left_wrist angle: 38.93 degrees
# Frame 183: right_wrist angle: 77.12 degrees
# Frame 183: left_ankle angle: 83.27 degrees
# Frame 183: right_ankle angle: 86.49 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 184: head angle: 19.58 degrees
# Frame 184: left_wrist angle: 35.84 degrees
# Frame 184: right_wrist angle: 76.70 degrees
# Frame 184: left_ankle angle: 84.79 degrees
# Frame 184: right_ankle angle: 85.73 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 185: head angle: 28.07 degrees
# Frame 185: left_wrist angle: 41.19 degrees
# Frame 185: right_wrist angle: 74.31 degrees
# Frame 185: left_ankle angle: 86.03 degrees
# Frame 185: right_ankle angle: 84.87 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 186: head angle: 40.68 degrees
# Frame 186: left_wrist angle: 39.29 degrees
# Frame 186: right_wrist angle: 71.45 degrees
# Frame 186: left_ankle angle: 11.31 degrees
# Frame 186: right_ankle angle: 83.72 degrees
# Processing video: .\Videos\impro_free.MP4
# Frame 187: head angle: 34.29 degrees
# Frame 187: left_wrist angle: 57.80 degrees
# Frame 187: right_wrist angle: 9.87 degrees
# Frame 187: left_ankle angle: 52.31 degrees
# Frame 187: right_ankle angle: 77.34 degrees
# Processing video: .\Videos\impro_free.MP4
# Processing video: .\Videos\impro_free.MP4
# Frame 189: head angle: 29.52 degrees
# Frame 189: left_wrist angle: 7.17 degrees
# Frame 189: right_wrist angle: 45.94 degrees
# Frame 189: left_ankle angle: 86.37 degrees
# Frame 189: right_ankle angle: 80.11 degrees
# Processing video: .\Videos\impro_free.MP4
# ...
# Frame 388: right_ankle angle: 73.25 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame
degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 402: head angle: 83.99 degrees
# Frame 402: left_wrist angle: 4.80 degrees
# Frame 402: right_wrist angle: 2.73 degrees
# Frame 402: left_ankle angle: 21.80 degrees
# Frame 402: right_ankle angle: 25.02 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 403: head angle: 84.62 degrees
# Frame 403: left_wrist angle: 3.76 degrees
# Frame 403: right_wrist angle: 6.34 degrees
# Frame 403: left_ankle angle: 6.63 degrees
# Frame 403: right_ankle angle: 5.91 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 404: head angle: 84.05 degrees
# Frame 404: left_wrist angle: 1.13 degrees
# Frame 404: right_wrist angle: 9.40 degrees
# Frame 404: left_ankle angle: 31.76 degrees
# Frame 404: right_ankle angle: 56.31 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 405: head angle: 84.54 degrees
# Frame 405: left_wrist angle: 0.00 degrees
# Frame 405: right_wrist angle: 11.78 degrees
# Frame 405: left_ankle angle: 48.54 degrees
# Frame 405: right_ankle angle: 79.11 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 406: head angle: 84.40 degrees
# Frame 406: left_wrist angle: 0.35 degrees
# Frame 406: right_wrist angle: 11.70 degrees
# Frame 406: left_ankle angle: 43.92 degrees
# Frame 406: right_ankle angle: 78.27 degrees
# Processed angles for frame 406:
# Processing video: .\Videos\Phrase3.mp4
# Frame 407: head angle: 81.13 degrees
# Frame 407: left_wrist angle: 1.00 degrees
# Frame 407: right_wrist angle: 12.88 degrees
# Frame 407: left_ankle angle: 67.88 degrees
# Frame 407: right_ankle angle: 89.62 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 408: head angle: 80.68 degrees
# Frame 408: left_wrist angle: 0.63 degrees
# Frame 408: right_wrist angle: 10.93 degrees
# Frame 408: left_ankle angle: 65.43 degrees
# Frame 408: right_ankle angle: 86.71 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 409: head angle: 78.80 degrees
# Frame 409: left_wrist angle: 5.05 degrees
# Frame 409: right_wrist angle: 2.90 degrees
# Frame 409: left_ankle angle: 65.98 degrees
# Frame 409: right_ankle angle: 87.82 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 410: head angle: 63.43 degrees
# Frame 410: left_wrist angle: 8.36 degrees
# Frame 410: right_wrist angle: 1.07 degrees
# Frame 410: left_ankle angle: 67.32 degrees
# Frame 410: right_ankle angle: 88.95 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 411: head angle: 65.66 degrees
# Frame 411: left_wrist angle: 9.36 degrees
# Frame 411: right_wrist angle: 2.19 degrees
# Frame 411: left_ankle angle: 67.38 degrees
# Frame 411: right_ankle angle: 88.49 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 412: head angle: 64.03 degrees
# Frame 412: left_wrist angle: 10.05 degrees
# Frame 412: right_wrist angle: 2.92 degrees
# Frame 412: left_ankle angle: 65.63 degrees
# Frame 412: right_ankle angle: 88.69 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 413: head angle: 68.20 degrees
# Frame 413: left_wrist angle: 3.60 degrees
# Frame 413: right_wrist angle: 5.49 degrees
# Frame 413: left_ankle angle: 63.31 degrees
# Frame 413: right_ankle angle: 88.73 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 414: head angle: 73.14 degrees
# Frame 414: left_wrist angle: 30.58 degrees
# Frame 414: right_wrist angle: 5.56 degrees
# Frame 414: left_ankle angle: 49.40 degrees
# Frame 414: right_ankle angle: 86.67 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 415: head angle: 86.63 degrees
# Frame 415: left_wrist angle: 38.93 degrees
# Frame 415: right_wrist angle: 8.97 degrees
# Frame 415: left_ankle angle: 54.71 degrees
# Frame 415: right_ankle angle: 83.59 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame
degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 497: head angle: 68.20 degrees
# Frame 497: left_wrist angle: 33.33 degrees
# Frame 497: right_wrist angle: 39.29 degrees
# Frame 497: left_ankle angle: 53.59 degrees
# Frame 497: right_ankle angle: 50.33 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 498: head angle: 77.47 degrees
# Frame 498: left_wrist angle: 48.25 degrees
# Frame 498: right_wrist angle: 12.53 degrees
# Frame 498: left_ankle angle: 53.19 degrees
# Frame 498: right_ankle angle: 50.28 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 499: head angle: 53.53 degrees
# Frame 499: left_wrist angle: 29.15 degrees
# Frame 499: right_wrist angle: 45.00 degrees
# Frame 499: left_ankle angle: 50.57 degrees
# Frame 499: right_ankle angle: 50.84 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 500: head angle: 33.69 degrees
# Frame 500: left_wrist angle: 26.83 degrees
# Frame 500: right_wrist angle: 32.17 degrees
# Frame 500: left_ankle angle: 46.15 degrees
# Frame 500: right_ankle angle: 50.51 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 501: head angle: 38.05 degrees
# Frame 501: left_wrist angle: 28.54 degrees
# Frame 501: right_wrist angle: 37.14 degrees
# Frame 501: left_ankle angle: 45.38 degrees
# Frame 501: right_ankle angle: 52.45 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 502: head angle: 40.24 degrees
# Frame 502: left_wrist angle: 2.56 degrees
# Frame 502: right_wrist angle: 37.54 degrees
# Frame 502: left_ankle angle: 45.96 degrees
# Frame 502: right_ankle angle: 53.71 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 503: head angle: 45.00 degrees
# Frame 503: left_wrist angle: 67.93 degrees
# Frame 503: right_wrist angle: 38.98 degrees
# Frame 503: left_ankle angle: 45.92 degrees
# Frame 503: right_ankle angle: 52.90 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 504: head angle: 43.88 degrees
# Frame 504: left_wrist angle: 86.86 degrees
# Frame 504: right_wrist angle: 39.86 degrees
# Frame 504: left_ankle angle: 45.17 degrees
# Frame 504: right_ankle angle: 50.98 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 505: head angle: 46.22 degrees
# Frame 505: left_wrist angle: 69.56 degrees
# Frame 505: right_wrist angle: 40.38 degrees
# Frame 505: left_ankle angle: 44.19 degrees
# Frame 505: right_ankle angle: 50.75 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 506: head angle: 18.43 degrees
# Frame 506: left_wrist angle: 15.99 degrees
# Frame 506: right_wrist angle: 39.91 degrees
# Frame 506: left_ankle angle: 50.44 degrees
# Frame 506: right_ankle angle: 53.80 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 507: head angle: 20.77 degrees
# Frame 507: left_wrist angle: 87.31 degrees
# Frame 507: right_wrist angle: 39.32 degrees
# Frame 507: left_ankle angle: 50.85 degrees
# Frame 507: right_ankle angle: 54.05 degrees
# Processing video: .\Videos\Phrase3.mp4
# Frame 508: head angle: 20.14 degrees
# Frame 508: left_wrist angle: 85.06 degrees
# Frame 508: right_wrist angle: 39.14 degrees
# Frame 508: left_ankle angle: 50.95 degrees
# Frame 508: right_ankle angle: 53.03 degrees
# End of video or cannot read the frame.

# %%
landmark_processed_data.head()
# Out:
#   Frame      Time  head_Angle  head_Velocity  head_Acceleration  \
# 0     1  0.034483   89.596515       0.202448          -0.000705
# 1     2  0.068966   89.798963       0.201742          -0.050965
# 2     3  0.103448   90.000000       0.100518          -0.100871
# 3     4  0.137931   90.000000       0.000000          -0.100874
# 4     5  0.172414   90.000000      -0.101229          -0.152377
#
#    left_wrist_Angle  left_wrist_Velocity  left_wrist_Acceleration  \
# 0         69.863697             0.203767                -0.120883
# 1         70.067463             0.082884                -0.145924
# 2         70.029464            -0.088082                -0.016437
# 3         69.891300             0.050010                 0.081674
# 4         70.129483             0.075266                -0.022128
#
#    right_wrist_Angle  right_wrist_Velocity  ...  \
# 0          77.157246              0.019489  ...
# 1          77.176735              0.202603  ...
# 2          77.562452              0.267471  ...
# 3          77.711677              0.185818  ...
# 4          77.934088              0.220965  ...
#
#    right_wrist_Velocity_normalized  right_wrist_Acceleration_normalized  \
# 0                         0.145172                             0.933033
# 1                         0.302245                             0.835488
# 2                         0.357889                             0.617074
# 3                         0.287848                             0.592555
# 4                         0.317996                             0.591230
#
#    left_ankle_Angle_filtered  left_ankle_Velocity_normalized  \
# 0                  82.849592                        0.835104
# 1                  83.096864                        0.944829
# 2                  83.326555                        1.000000
# 3                  83.523324                        0.970152
# 4                  83.675338                        0.794827
#
#    left_ankle_Acceleration_normalized  right_ankle_Angle_filtered  \
# 0                            0.788211                   79.164269
# 1                            0.750313                   79.035187
# 2                            0.653356                   78.926534
# 3                            0.493238                   78.853720
# 4                            0.357994                   78.822561
#
#    right_ankle_Velocity_normalized  right_ankle_Acceleration_normalized  \
# 0                         0.129473                             0.459212
# 1                         0.178955                             0.547785
# 2                         0.376012                             0.490789
# 3                         0.330529                             0.516820
# 4                         0.570958                             0.688210
#
#    Classification   Video Name
# 0        indirect  Phrase3.mp4
# 1        indirect  Phrase3.mp4
# 2        indirect  Phrase3.mp4
# 3        indirect  Phrase3.mp4
# 4        indirect  Phrase3.mp4
#
# [5 rows x 34 columns]

# %%
# Group by each second (using integer part of 'Time') and aggregate min, max, mean for all columns except 'Classification', 'Video Name', and 'Frame'
grouped_stats = landmark_processed_data.groupby(landmark_processed_data['Time'].astype(int)).agg(
    {col: ['min', 'max', 'mean'] for col in landmark_processed_data.columns if col not in ['Classification', 'Video Name', 'Frame', 'Time']}
)

# Optionally, reset index for a flat DataFrame
grouped_stats = grouped_stats.reset_index()

grouped_stats.head(30)
# Out:
#    Time head_Angle                       head_Velocity                       \
#                min        max       mean           min        max      mean
# 0     0  88.152390  90.000000  88.919953     -0.407890   0.504312  0.007180
# 1     1  78.558956  90.000000  87.060401     -1.432399   0.607353 -0.404344
# 2     2  69.443955  88.115950  76.011321     -1.984765   1.913097  0.369683
# 3     3  69.274441  89.660976  83.701568     -6.942960   7.193437 -0.398744
# 4     4  30.579227  90.000000  66.709602    -21.069077   7.577621 -1.009126
# 5     5  21.801409  85.601295  50.872234    -30.472698  13.632764 -1.281855
# 6     6  50.659482  69.489141  65.266073     -0.609465   4.536179  0.696707
# 7     7  68.270210  83.271488  75.629307     -0.994556   1.287345  0.510610
# 8     8  80.630615  89.716360  84.368865     -1.009184   1.359051 -0.108550
# 9     9  81.792784  90.000000  86.716261     -0.122426   0.742983  0.283090
# 10   10  87.492298  90.000000  89.339876     -0.626798   0.245903 -0.066819
# 11   11  85.634742  87.887589  86.387104     -0.426717   0.356613  0.024272
# 12   12  81.702855  89.714949  87.268781     -1.402410   0.385486 -0.205270
# 13   13  73.855661  84.999355  79.977049     -1.479716   1.378995  0.109737
# 14   14  63.434949  89.104826  77.068360    -12.419415   9.217474 -1.399619
# 15   16  72.758541  83.290163  76.575956      0.728021   4.897262  2.590858
# 16   17  82.234834  82.234834  82.234834     -1.055329  -1.055329 -1.055329
#
#    head_Acceleration                       ...  \
#                  min        max      mean  ...
# 0          -0.157271   0.256128  0.012608  ...
# 1          -0.694088   0.352220 -0.044576  ...
# 2          -0.615726   0.667698 -0.015635  ...
# 3          -4.885362   7.068198  0.159522  ...
# 4         -11.651328   4.660732 -1.061592  ...
# 5         -15.011384  16.199009 -0.965244  ...
# 6          -0.694029   0.481535 -0.142494  ...
# 7          -0.424363   0.576224 -0.010820  ...
# 8          -0.656817   0.589031  0.036125  ...
# 9          -0.250104   0.269430  0.000988  ...
# 10         -0.213358   0.212852  0.007154  ...
# 11         -0.422130   0.201213 -0.008667  ...
# 12         -0.694133   0.825247 -0.013820  ...
# 13         -0.722082   0.710106  0.046491  ...
# 14         -6.095494   4.458029 -0.804204  ...
# 15         -2.976296   2.084621  0.183434  ...
# 16         -3.793006  -3.793006 -3.793006  ...
#
#    left_ankle_Acceleration_normalized right_ankle_Angle_filtered             \
#                                  mean                        min        max
# 0                            0.609205                  78.606578  79.164269
# 1                            0.534077                  79.077967  82.324973
# 2                            0.536828                  59.885155  82.288132
# 3                            0.478043                  24.971375  95.210078
# 4                            0.455509                   9.744890  29.723941
# 5                            0.484495                  20.536238  61.728747
# 6                            0.505371                  50.547509  66.577612
# 7                            0.599135                  67.020855  86.363998
# 8                            0.592017                  85.623530  88.923714
# 9                            0.348755                  78.406333  85.046453
# 10                           0.644153                  80.262623  85.645913
# 11                           0.442463                  79.379727  82.293107
# 12                           0.621786                  77.541667  79.515855
# 13                           0.413289                  35.324736  77.407690
# 14                           0.599378                  40.230259  90.128935
# 15                           0.641377                  38.837703  48.274634
# 16                           0.677763                  53.073982  53.073982
#
#               right_ankle_Velocity_normalized                      \
#          mean                             min       max      mean
# 0   78.855838                        0.000000  1.000000  0.512167
# 1   80.141146                        0.000000  1.000000  0.433571
# 2   73.595909                        0.000000  1.000000  0.610129
# 3   55.274897                        0.000000  1.000000  0.489554
# 4   18.686147                        0.180905  0.804978  0.478927
# 5   48.192861                        0.232090  0.883489  0.473695
# 6   58.607357                        0.000000  1.000000  0.388183
# 7   78.569869                        0.000100  1.000000  0.507098
# 8   87.328865                        0.000000  1.000000  0.647953
# 9   80.796775                        0.000000  1.000000  0.480541
# 10  84.084464                        0.000000  1.000000  0.492752
# 11  80.964288                        0.000000  1.000000  0.359043
# 12  78.574696                        0.135462  1.000000  0.655465
# 13  63.309758                        0.000000  1.000000  0.342204
# 14  76.827598                        0.000000  1.000000  0.678365
# 15  42.821133                        0.766919  0.850944  0.808615
# 16  53.073982                        0.848063  0.848063  0.848063
#
#    right_ankle_Acceleration_normalized
#                                    min       max      mean
# 0                             0.000000  1.000000  0.427331
# 1                             0.000000  1.000000  0.540892
# 2                             0.000000  1.000000  0.481391
# 3                             0.000000  1.000000  0.457222
# 4                             0.097290  0.858928  0.504893
# 5                             0.118130  0.840517  0.503663
# 6                             0.000000  1.000000  0.542611
# 7                             0.000000  1.000000  0.525185
# 8                             0.000000  1.000000  0.571898
# 9                             0.000000  1.000000  0.401810
# 10                            0.000000  1.000000  0.598686
# 11                            0.000000  0.920514  0.587555
# 12                            0.000000  1.000000  0.677211
# 13                            0.000000  1.000000  0.391223
# 14                            0.000000  1.000000  0.326234
# 15                            0.266857  0.333014  0.291788
# 16                            0.335961  0.335961  0.335961
#
# [17 rows x 91 columns]

# %%
# Group by each second
landmark_grouped_processed_data = landmark_processed_data.groupby(landmark_processed_data['Time'].astype(int))
landmark_grouped_processed_data = landmark_grouped_processed_data.agg({
            'Filtered Angle (degrees)': ['std', 'mean', 'min', 'max'],
            'velocity': ['std', 'mean', 'min', 'max'],
            'acceleration': ['std', 'mean', 'min', 'max']
        }).reset_index()
    # Flatten MultiIndex columns
landmark_grouped_processed_data.columns = ['Time (seconds)',
                        'angle_std', 'angle_mean', 'angle_min', 'angle_max',
                        'velocity_std', 'velocity_mean',  'velocity_min', 'velocity_max',
                        'acceleration_std', 'acceleration_mean', 'acceleration_min', 'acceleration_max']
landmark_grouped_processed_data.to_csv(os.path.join(data_folder, 'all_landmarks_data_Processed_combined.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Group by each second
#       2 landmark_grouped_processed_data = landmark_processed_data.groupby(landmark_processed_data['Time'].astype(int))
# ----> 3 landmark_grouped_processed_data = landmark_grouped_processed_data.agg({
#       4             'Filtered Angle (degrees)': ['std', 'mean', 'min', 'max'],
#       5             'velocity': ['std', 'mean', 'min', 'max'],
#       6             'acceleration': ['std', 'mean', 'min', 'max']
#       7         }).reset_index()
#       8     # Flatten MultiIndex columns
#       9 landmark_grouped_processed_data.columns = ['Time (seconds)',
#      10                         'angle_std', 'angle_mean', 'angle_min', 'angle_max',
#      11                         'velocity_std', 'velocity_mean',  'velocity_min', 'velocity_max',
#      12                         'acceleration_std', 'acceleration_mean', 'acceleration_min', 'acceleration_max']
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File c:\Users\asus\Desktop\Laban_Dance_Analysis\clean_env\lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Filtered Angle (degrees)', 'acceleration', 'velocity'] do not exist"

# %% [markdown]
# ### **Print DataFrame statistics**

# %%
landmark_processed_data.describe(include='all')
# Out:
#         Time (seconds)   Video Name Classification  angle_std_head  \
# count        24.000000           24             24       24.000000
# unique             NaN            2              2             NaN
# top                NaN  Phrase3.mp4       indirect             NaN
# freq               NaN           16             16             NaN
# mean          6.208333          NaN            NaN        6.949454
# std           4.596588          NaN            NaN        6.830514
# min           0.000000          NaN            NaN        0.582127
# 25%           2.750000          NaN            NaN        2.022171
# 50%           5.500000          NaN            NaN        5.131147
# 75%           9.250000          NaN            NaN        7.487571
# max          16.000000          NaN            NaN       25.168462
#
#         angle_medium_head  angle_median_head  angle_min_head  angle_max_head  \
# count           24.000000          24.000000       24.000000       24.000000
# unique                NaN                NaN             NaN             NaN
# top                   NaN                NaN             NaN             NaN
# freq                  NaN                NaN             NaN             NaN
# mean            76.054129          76.617481       64.868327       85.695832
# std             13.972433          14.960603       22.647242        5.106455
# min             40.900191          32.344184       16.187134       71.978330
# 25%             72.245347          74.197294       60.644802       82.056637
# 50%             80.550428          81.412039       73.433874       88.645806
# 75%             86.375945          87.382549       77.821015       89.306147
# max             88.947236          89.508877       88.294134       90.362379
#
#         velocity_std_head  velocity_medium_head  ...  \
# count           24.000000             24.000000  ...
# unique                NaN                   NaN  ...
# top                   NaN                   NaN  ...
# freq                  NaN                   NaN  ...
# mean             1.185817             -0.167940  ...
# std              1.236374              1.235671  ...
# min              0.098639             -2.831424  ...
# 25%              0.326264             -0.468678  ...
# 50%              0.854609             -0.000666  ...
# 75%              1.802350              0.229123  ...
# max              5.387015              2.342328  ...
#
#         velocity_std_right_ankle  velocity_medium_right_ankle  \
# count                  24.000000                    24.000000
# unique                       NaN                          NaN
# top                          NaN                          NaN
# freq                         NaN                          NaN
# mean                    1.793486                    -0.473514
# std                     1.895642                     1.728296
# min                     0.145687                    -6.294967
# 25%                     0.353615                    -0.422123
# 50%                     1.450209                    -0.101117
# 75%                     2.237565                     0.296474
# max                     8.081774                     1.978879
#
#         velocity_median_right_ankle  velocity_min_right_ankle  \
# count                     24.000000                 24.000000
# unique                          NaN                       NaN
# top                             NaN                       NaN
# freq                            NaN                       NaN
# mean                      -0.603870                 -3.392260
# std                        1.748803                  3.285879
# min                       -6.471038                -12.586660
# 25%                       -0.777490                 -4.751074
# 50%                        0.000029                 -2.568866
# 75%                        0.268928                 -0.674596
# max                        0.944584                  0.235812
#
#         velocity_max_right_ankle  acceleration_std_right_ankle  \
# count                  24.000000                     24.000000
# unique                       NaN                           NaN
# top                          NaN                           NaN
# freq                         NaN                           NaN
# mean                    2.788511                      0.645593
# std                     4.399260                      0.681255
# min                    -5.708411                      0.035762
# 25%                     0.384817                      0.108259
# 50%                     1.516738                      0.418743
# 75%                     4.266979                      1.037263
# max                    14.162098                      2.971016
#
#         acceleration_medium_right_ankle  acceleration_median_right_ankle  \
# count                         24.000000                        24.000000
# unique                              NaN                              NaN
# top                                 NaN                              NaN
# freq                                NaN                              NaN
# mean                           0.022661                         0.011727
# std                            0.434993                         0.444971
# min                           -0.594921                        -0.561045
# 25%                           -0.117442                        -0.076093
# 50%                           -0.011002                        -0.015382
# 75%                            0.012648                         0.022313
# max                            1.899829                         1.899829
#
#         acceleration_min_right_ankle  acceleration_max_right_ankle
# count                      24.000000                     24.000000
# unique                           NaN                           NaN
# top                              NaN                           NaN
# freq                             NaN                           NaN
# mean                       -1.111216                      1.146996
# std                         1.315427                      1.373732
# min                        -4.416133                     -0.234414
# 25%                        -2.072895                      0.157304
# 50%                        -0.711759                      0.700782
# 75%                        -0.142418                      1.745160
# max                         1.665823                      5.344058
#
# [11 rows x 78 columns]

# %%
landmark_processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Time (seconds)                   24 non-null     int32
#  1   Video Name                       24 non-null     object
#  2   Classification                   24 non-null     object
#  3   angle_std_head                   24 non-null     float64
#  4   angle_medium_head                24 non-null     float64
#  5   angle_median_head                24 non-null     float64
#  6   angle_min_head                   24 non-null     float64
#  7   angle_max_head                   24 non-null     float64
#  8   velocity_std_head                24 non-null     float64
#  9   velocity_medium_head             24 non-null     float64
#  10  velocity_median_head             24 non-null     float64
#  11  velocity_min_head                24 non-null     float64
#  12  velocity_max_head                24 non-null     float64
#  13  acceleration_std_head            24 non-null     float64
#  14  acceleration_medium_head         24 non-null     float64
#  15  acceleration_median_head         24 non-null     float64
#  16  acceleration_min_head            24 non-null     float64
#  17  acceleration_max_head            24 non-null     float64
#  18  angle_std_left_wrist             24 non-null     float64
#  19  angle_medium_left_wrist          24 non-null     float64
#  20  angle_median_left_wrist          24 non-null     float64
#  21  angle_min_left_wrist             24 non-null     float64
#  22  angle_max_left_wrist             24 non-null     float64
#  23  velocity_std_left_wrist          24 non-null     float64
#  24  velocity_medium_left_wrist       24 non-null     float64
#  25  velocity_median_left_wrist       24 non-null     float64
#  26  velocity_min_left_wrist          24 non-null     float64
#  27  velocity_max_left_wrist          24 non-null     float64
#  28  acceleration_std_left_wrist      24 non-null     float64
#  29  acceleration_medium_left_wrist   24 non-null     float64
#  30  acceleration_median_left_wrist   24 non-null     float64
#  31  acceleration_min_left_wrist      24 non-null     float64
#  32  acceleration_max_left_wrist      24 non-null     float64
#  33  angle_std_right_wrist            24 non-null     float64
#  34  angle_medium_right_wrist         24 non-null     float64
#  35  angle_median_right_wrist         24 non-null     float64
#  36  angle_min_right_wrist            24 non-null     float64
#  37  angle_max_right_wrist            24 non-null     float64
#  38  velocity_std_right_wrist         24 non-null     float64
#  39  velocity_medium_right_wrist      24 non-null     float64
#  40  velocity_median_right_wrist      24 non-null     float64
#  41  velocity_min_right_wrist         24 non-null     float64
#  42  velocity_max_right_wrist         24 non-null     float64
#  43  acceleration_std_right_wrist     24 non-null     float64
#  44  acceleration_medium_right_wrist  24 non-null     float64
#  45  acceleration_median_right_wrist  24 non-null     float64
#  46  acceleration_min_right_wrist     24 non-null     float64
#  47  acceleration_max_right_wrist     24 non-null     float64
#  48  angle_std_left_ankle             24 non-null     float64
#  49  angle_medium_left_ankle          24 non-null     float64
#  50  angle_median_left_ankle          24 non-null     float64
#  51  angle_min_left_ankle             24 non-null     float64
#  52  angle_max_left_ankle             24 non-null     float64
#  53  velocity_std_left_ankle          24 non-null     float64
#  54  velocity_medium_left_ankle       24 non-null     float64
#  55  velocity_median_left_ankle       24 non-null     float64
#  56  velocity_min_left_ankle          24 non-null     float64
#  57  velocity_max_left_ankle          24 non-null     float64
#  58  acceleration_std_left_ankle      24 non-null     float64
#  59  acceleration_medium_left_ankle   24 non-null     float64
#  60  acceleration_median_left_ankle   24 non-null     float64
#  61  acceleration_min_left_ankle      24 non-null     float64
#  62  acceleration_max_left_ankle      24 non-null     float64
#  63  angle_std_right_ankle            24 non-null     float64
#  64  angle_medium_right_ankle         24 non-null     float64
#  65  angle_median_right_ankle         24 non-null     float64
#  66  angle_min_right_ankle            24 non-null     float64
#  67  angle_max_right_ankle            24 non-null     float64
#  68  velocity_std_right_ankle         24 non-null     float64
#  69  velocity_medium_right_ankle      24 non-null     float64
#  70  velocity_median_right_ankle      24 non-null     float64
#  71  velocity_min_right_ankle         24 non-null     float64
#  72  velocity_max_right_ankle         24 non-null     float64
#  73  acceleration_std_right_ankle     24 non-null     float64
#  74  acceleration_medium_right_ankle  24 non-null     float64
#  75  acceleration_median_right_ankle  24 non-null     float64
#  76  acceleration_min_right_ankle     24 non-null     float64
#  77  acceleration_max_right_ankle     24 non-null     float64
# dtypes: float64(75), int32(1), object(2)
# memory usage: 14.7+ KB
